# %%
from matplotlib import pyplot as plt
import math

# %%
request_list = [131, 85, 86, 173, 82, 170, 83, 198, 165, 106]
curr_head = 50
max_cylinder = 199

# %%
def CLOOK(request_list, curr_head, moving_direction):
    temp_list = request_list.copy()
    left_request_request_request = []    
    right_request = []
    x = []
    y = []
    x.append(curr_head)
    if(moving_direction=="left"):
        for i in temp_list:
            if i<curr_head:
                left_request_request_request.append(i)
            else:
                right_request.append(i)
        left_request_request_request.sort(reverse = True)
        for i in left_request_request_request:
            x.append(i)
        right_request.sort(reverse = True)
        for i in right_request:
            x.append(i)
    elif(moving_direction=="right"):
        for i in temp_list:
            if i>curr_head:
                right_request.append(i)
            else:
                left_request_request_request.append(i)
        right_request.sort()
        for i in right_request:
            x.append(i)
        left_request_request_request.sort()
        for i in left_request_request_request:
            x.append(i) 
    
    size = len(x)
    for i in range(0,size):
        y.append(-i)

    plt.figure(figsize=(10, 5))
    plt.xticks(range(0, max_cylinder + 1, 20))
    plt.plot(x,y, color="green", markerfacecolor = 'blue', marker='o', markersize = 5, linewidth = 2, label="CLOOK")
    plt.ylim = (0,size)
    plt.xlim = (0,max_cylinder)
    plt.yticks([])
    plt.title("C-LOOK Scheduling Algorithm")
    plt.show()

# %%
CLOOK(request_list,curr_head,"right")

# %%
request_list = [134, 2, 167, 121, 181, 45, 130, 77, 199, 72, 102, 155, 64, 178, 137, 5, 148, 28, 164, 141]
curr_head = 50
max_cylinder = 199

# %%
def CLOOK(request_list, curr_head, moving_direction):
    temp_list = request_list.copy()
    left_request_request_request = []    
    right_request = []
    x = []
    y = []
    x.append(curr_head)
    if(moving_direction=="left"):
        for i in temp_list:
            if i<curr_head:
                left_request_request_request.append(i)
            else:
                right_request.append(i)
        left_request_request_request.sort(reverse = True)
        for i in left_request_request_request:
            x.append(i)
        right_request.sort(reverse = True)
        for i in right_request:
            x.append(i)
    elif(moving_direction=="right"):
        for i in temp_list:
            if i>curr_head:
                right_request.append(i)
            else:
                left_request_request_request.append(i)
        right_request.sort()
        for i in right_request:
            x.append(i)
        left_request_request_request.sort()
        for i in left_request_request_request:
            x.append(i) 
    
    size = len(x)
    for i in range(0,size):
        y.append(-i)

    plt.figure(figsize=(10, 5))
    plt.xticks(range(0, max_cylinder + 1, 20))
    plt.plot(x,y, color="green", markerfacecolor = 'blue', marker='o', markersize = 5, linewidth = 2, label="CLOOK")
    plt.ylim = (0,size)
    plt.xlim = (0,max_cylinder)
    plt.yticks([])
    plt.title("C-LOOK Scheduling Algorithm")
    plt.show()

# %%
CLOOK(request_list,curr_head,"right")

# %%
request_list =  [110, 85, 63, 4, 157, 37, 189, 108, 45, 79, 175, 156, 95, 31, 174, 148, 163, 168, 142, 87, 155, 73, 40, 19, 165, 74, 11, 199, 64, 101, 14, 9, 112, 141, 133, 23, 26, 105, 33, 166, 147, 167, 55, 21, 134, 35, 178, 118, 198, 84]
curr_head = 50
max_cylinder = 199

# %%
def CLOOK(request_list, curr_head, moving_direction):
    temp_list = request_list.copy()
    left_request_request_request = []    
    right_request = []
    x = []
    y = []
    x.append(curr_head)
    if(moving_direction=="left"):
        for i in temp_list:
            if i<curr_head:
                left_request_request_request.append(i)
            else:
                right_request.append(i)
        left_request_request_request.sort(reverse = True)
        for i in left_request_request_request:
            x.append(i)
        right_request.sort(reverse = True)
        for i in right_request:
            x.append(i)
    elif(moving_direction=="right"):
        for i in temp_list:
            if i>curr_head:
                right_request.append(i)
            else:
                left_request_request_request.append(i)
        right_request.sort()
        for i in right_request:
            x.append(i)
        left_request_request_request.sort()
        for i in left_request_request_request:
            x.append(i) 
    
    size = len(x)
    for i in range(0,size):
        y.append(-i)

    plt.figure(figsize=(10, 5))
    plt.xticks(range(0, max_cylinder + 1, 20))
    plt.plot(x,y, color="green", markerfacecolor = 'blue', marker='o', markersize = 5, linewidth = 2, label="CLOOK")
    plt.ylim = (0,size)
    plt.xlim = (0,max_cylinder)
    plt.yticks([])
    plt.title("C-LOOK Scheduling Algorithm")
    plt.show()

# %%
CLOOK(request_list,curr_head,"right")

# %%
request_list =  [3, 88, 99, 170, 101, 133, 26, 59, 144, 43, 29, 147, 181, 12, 122, 98, 113, 58, 48, 41, 79, 189, 14, 171, 7, 114, 46, 104, 107, 80, 74, 87, 85, 136, 70, 156, 176, 177, 158, 108, 18, 66, 68, 81, 116, 123, 20, 137, 32, 167, 120, 90, 22, 110, 146, 71, 33, 65, 178, 63, 36, 126, 23, 128, 76, 53, 157, 164, 184, 162, 72, 78, 40, 24, 175, 115, 199, 2, 38, 1, 95, 117, 197, 188, 127, 89, 187, 62, 141, 84, 118, 151, 169, 134, 73, 100, 183, 67, 56, 172]
curr_head = 50
max_cylinder = 199

# %%
def CLOOK(request_list, curr_head, moving_direction):
    temp_list = request_list.copy()
    left_request_request_request = []    
    right_request = []
    x = []
    y = []
    x.append(curr_head)
    if(moving_direction=="left"):
        for i in temp_list:
            if i<curr_head:
                left_request_request_request.append(i)
            else:
                right_request.append(i)
        left_request_request_request.sort(reverse = True)
        for i in left_request_request_request:
            x.append(i)
        right_request.sort(reverse = True)
        for i in right_request:
            x.append(i)
    elif(moving_direction=="right"):
        for i in temp_list:
            if i>curr_head:
                right_request.append(i)
            else:
                left_request_request_request.append(i)
        right_request.sort()
        for i in right_request:
            x.append(i)
        left_request_request_request.sort()
        for i in left_request_request_request:
            x.append(i) 
    
    size = len(x)
    for i in range(0,size):
        y.append(-i)

    plt.figure(figsize=(10, 5))
    plt.xticks(range(0, max_cylinder + 1, 20))
    plt.plot(x,y, color="green", markerfacecolor = 'blue', marker='o', markersize = 5, linewidth = 2, label="CLOOK")
    plt.ylim = (0,size)
    plt.xlim = (0,max_cylinder)
    plt.yticks([])
    plt.title("C-LOOK Scheduling Algorithm")
    plt.show()

# %%
CLOOK(request_list,curr_head,"right")
